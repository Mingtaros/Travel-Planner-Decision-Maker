# %% [markdown]
# Basically doing the same thing, but with CPLEX

# %%
time_brackets = [8, 12, 16, 20]

# %%
import json

def get_transport_matrix():
    BASE_PATH = "../data/routeData/"
    daytimes = [("morning", 8), ("midday", 12), ("evening", 16), ("night", 20)]
    transport_matrix = {}

    for time_in_day, hour in daytimes:
        filepath = BASE_PATH + f"route_matrix_{time_in_day}.json"

        with open(filepath, 'r') as f:
            route_matrix = json.load(f)

        for route in route_matrix["routes"]:
            this_route = route_matrix["routes"][route]
            origin = this_route["origin_name"]
            destination = this_route["destination_name"]
            transport_matrix[(origin, destination, hour)] = {
                "transit": {
                    "duration": this_route["transit"]["duration_minutes"],
                    "price": this_route["transit"]["fare_sgd"],
                },
                "drive": {
                    "duration": this_route["drive"]["duration_minutes"],
                    "price": this_route["drive"]["fare_sgd"],
                }
            }
    
    return transport_matrix


def get_all_locations():
    BASE_PATH = "../data/routeData/"

    with open(BASE_PATH + "route_matrix_morning.json", 'r') as f:
        route_matrix = json.load(f)
    
    locations = [route_matrix["locations"][location_id] for location_id in route_matrix["locations"]]
    return locations


def get_transport_hour(transport_time):
    # because the transport_matrix is only bracketed to 4 groups, we find the earliest it happens
    transport_hour = transport_time // 60

    for bracket in reversed(time_brackets):
        if transport_hour >= bracket:
            return bracket

    return transport_brackets[-1] # from 8 PM to 8 AM next day

# %%
import numpy as np

# %%
all_locations = get_all_locations()

# for all locations, get satisfaction and rating
for loc in all_locations:
    if loc["type"] == "hawker":
        loc["rating"] = np.random.randint(0, 5)
        loc["avg_food_price"] = np.random.randint(5, 15)
        loc["duration"] = 60 # just standardize 60 mins
    elif loc["type"] == "attraction":
        loc["satisfaction"] = np.random.randint(0, 10)
        loc["entrance_fee"] = np.random.randint(5, 100)
        loc["duration"] = np.random.randint(30, 90)

dummy_hotel = {
    "type": "hotel",
    "name": "DUMMY HOTEL",
    "lat": 1.2852044,
    "lng": 103.8610313,
}

# %%
transport_matrix = get_transport_matrix()
# add dummy hotel to transport_matrix
for loc in all_locations:
    for time_ in time_brackets:
        transport_matrix[(dummy_hotel["name"], loc["name"], time_)] = {
            "transit": {
                "duration": 50,
                "price": 1.93,
            },
            "drive": {
                "duration": 20,
                "price": 10.1,
            }
        }
        transport_matrix[(loc["name"], dummy_hotel["name"], time_)] = {
            "transit": {
                "duration": 50,
                "price": 1.93,
            },
            "drive": {
                "duration": 20,
                "price": 10.1,
            }
        }

locations = [dummy_hotel] + all_locations

# %%
import random
random.seed(42)

hotels = [loc for loc in locations if loc["type"] == "hotel"]
attractions = [loc for loc in locations if loc["type"] == "attraction"]
hawkers = [loc for loc in locations if loc["type"] == "hawker"]

selected_hotel = random.sample(hotels, 1)
selected_attractions = random.sample(attractions, 5)
selected_hawkers = random.sample(hawkers, 2)

selected_locations = selected_hotel + selected_attractions + selected_hawkers

# %%
selected_locations
# Out:
# [{'type': 'hotel',
#   'name': 'DUMMY HOTEL',
#   'lat': 1.2852044,
#   'lng': 103.8610313},
#  {'id': 'A4',
#   'name': 'ArtScience Museum',
#   'type': 'attraction',
#   'lat': 1.2862738,
#   'lng': 103.8592663,
#   'satisfaction': 0,
#   'entrance_fee': 46,
#   'duration': 55},
#  {'id': 'A7',
#   'name': 'National Museum of Singapore',
#   'type': 'attraction',
#   'lat': 1.296613,
#   'lng': 103.8485091,
#   'satisfaction': 0,
#   'entrance_fee': 66,
#   'duration': 35},
#  {'id': 'A13',
#   'name': 'Esplanade',
#   'type': 'attraction',
#   'lat': 1.2897934,
#   'lng': 103.8558166,
#   'satisfaction': 8,
#   'entrance_fee': 29,
#   'duration': 84},
#  {'id': 'A11',
#   'name': 'Clarke Quay',
#   'type': 'attraction',
#   'lat': 1.2906024,
#   'lng': 103.8464742,
#   'satisfaction': 7,
#   'entrance_fee': 46,
#   'duration': 71},
#  {'id': 'A12',
#   'name': 'Orchard Road',
#   'type': 'attraction',
#   'lat': 1.3048205,
#   'lng': 103.8321984,
#   'satisfaction': 4,
#   'entrance_fee': 72,
#   'duration': 51},
#  {'id': 'H3',
#   'name': 'Hill Street Tai Hwa Pork Noodle',
#   'type': 'hawker',
#   'lat': 1.3051265,
#   'lng': 103.8625357,
#   'rating': 1,
#   'avg_food_price': 13,
#   'duration': 60},
#  {'id': 'H2',
#   'name': 'Amoy Street Food Centre',
#   'type': 'hawker',
#   'lat': 1.2794385,
#   'lng': 103.8466789,
#   'rating': 4,
#   'avg_food_price': 9,
#   'duration': 60}]

# %%
from docplex.mp.model import Model

# %%
mdl = Model("MITB-AI")

# %%
NUM_DAYS = 3
HOTEL_COST = 50
START_TIME = 9 * 60 # everyday starts from 9 AM
HARD_LIMIT_END_TIME = 22 * 60 # everyday MUST return back to hotel by 10 PM

# Define lunch and dinner time windows (in minutes since start of day at 9 AM)
LUNCH_START = 11 * 60  # 11 AM (9 AM + 2 hours)
LUNCH_END = 15 * 60    # 3 PM (9 AM + 6 hours)
DINNER_START = 17 * 60  # 5 PM (9 AM + 8 hours)
DINNER_END = 21 * 60   # 9 PM (9 AM + 12 hours)

# hard limit money spent
budget = 1000
# list of destinations
locations = locations
num_locations = len(locations)
num_attractions = len([loc for loc in locations if loc["type"] == "attraction"])
num_hawkers = len([loc for loc in locations if loc["type"] == "hawker"])
num_hotels = 1 # always 1

# transportation option prices and durations. The size MUST BE num_dest * num_dest, for 24 hours
transport_types = ["transit", "drive"]
num_transport_types = len(transport_types)

# %%
x_var = {
    (day, transport_type, source["name"], dest["name"]): mdl.binary_var(f"Day_{day}_GoFrom_{source['name']}_To_{dest['name']}_using_{transport_type}")
    for day in range(NUM_DAYS)
    for transport_type in transport_types
    for source in locations
    for dest in locations
    if source != dest
}

u_var = {
    (day, location["name"]): mdl.integer_var(0, HARD_LIMIT_END_TIME, name=f"Day_{day}_FinishAttraction_{location['name']}_time")
    for day in range(NUM_DAYS)
    for location in locations
}

bracket_var = {
    (day, location["name"], time_bracket): mdl.binary_var(f"Day_{day}_FinishAttraction_{location['name']}_time_bracket_{time_bracket}")
    for day in range(NUM_DAYS)
    for location in locations
    for time_bracket in time_brackets
}

last_visit_var = {
    (day, location["name"]): mdl.binary_var(name=f"Day_{day}_LastVisitIs_{location['name']}")
    for day in range(NUM_DAYS)
    for location in locations
}

lunch_hawker_visit_var = {
    (day, location["name"]): mdl.binary_var(name=f"Day_{day}_VisitHawker_{location['name']}_inLunchTime")
    for day in range(NUM_DAYS)
    for location in locations
    if location["type"] == "hawker"
}

dinner_hawker_visit_var = {
    (day, location["name"]): mdl.binary_var(name=f"Day_{day}_VisitHawker_{location['name']}_inDinnerTime")
    for day in range(NUM_DAYS)
    for location in locations
    if location["type"] == "hawker"
}

cost_var = mdl.continuous_var(lb=0, name="total_cost")
travel_time_var = mdl.continuous_var(lb=0, name="total_travel_time")
satisfaction_var = mdl.continuous_var(lb=0, name="total_satisfaction")

# %%
# every day, for every location, the time bracket the guy goes in, must be only 1, cannot go to multiple
for day in range(NUM_DAYS):
    for source in locations:
        mdl.add_constraint(
            sum(bracket_var[(day, source["name"], time_bracket)] for time_bracket in time_brackets) == 1
        )

# link bracket_var and u_var
LARGE_M = 10e6  # Large enough big-M constant
for day in range(NUM_DAYS):
    for source in locations:
        for time_bracket in time_brackets:
            mdl.add_constraint( # ensure that if this time bracket is chosen, then u_var must be bigger than the next bracket
                time_bracket * bracket_var[(day, source["name"], time_bracket)] <= u_var[(day, source["name"])].divide(60)
            )
            # if this time bracket is chosen, then it must be between this bracket and the next bracket
            mdl.add_constraint(
                u_var[(day, source["name"])].divide(60) <= (time_bracket + 4) * bracket_var[(day, source["name"], time_bracket)] +
                LARGE_M * (1 - bracket_var[(day, source["name"], time_bracket)])
            )

# make sure there's only 1 last visit every day
for day in range(NUM_DAYS):
    mdl.add_constraint(
        sum([last_visit_var[(day, loc["name"])] for loc in locations[1:]]) == 1
    )
    # link last visit with u_var
    for loc in locations:
        for other_loc in locations:
            mdl.add_constraint(
                u_var[(day, loc["name"])] <= u_var[(day, other_loc["name"])] +
                LARGE_M * (1 - last_visit_var[(day, other_loc["name"])])
            )
    # for everyday, last visit cannot be hotel
    mdl.add_constraint(last_visit_var[(day, locations[0]["name"])] == 0)

# for every attraction, must be a source & destination at most once
for loc in locations:
    if loc["type"] == "attraction":
        mdl.add_constraint(
            sum([
                x_var[(day, transport_type, loc["name"], dest["name"])]
                for day in range(NUM_DAYS)
                for transport_type in transport_types
                for dest in locations
                if loc != dest
            ]) <= 1
        )
        mdl.add_constraint(
            sum([
                x_var[(day, transport_type, source["name"], loc["name"])]
                for day in range(NUM_DAYS)
                for transport_type in transport_types
                for source in locations
                if loc != source
            ]) <= 1
        )

# for hawkers, every day must be a source & destination at most once
for day in range(NUM_DAYS):
    for loc in locations:
        if loc["type"] == "hawker":
            mdl.add_constraint(
                sum([
                    x_var[(day, transport_type, source["name"], loc["name"])]
                    for transport_type in transport_types
                    for source in locations
                    if source != loc
                ]) <= 1
            )
            mdl.add_constraint(
                sum([
                    x_var[(day, transport_type, loc["name"], dest["name"])]
                    for transport_type in transport_types
                    for dest in locations
                    if dest != loc
                ]) <= 1
            )

        # if attraction is a source, it must also be a destination
        mdl.add_constraint(
            sum([
                x_var[(day, transport_type, source["name"], loc["name"])]
                for transport_type in transport_types
                for source in locations
                if source != loc
            ]) == sum([
                x_var[(day, transport_type, loc["name"], dest["name"])]
                for transport_type in transport_types
                for dest in locations
                if dest != loc
            ])
        )

# link lunch & dinner hawker visit to u_var
for day in range(NUM_DAYS):
    for loc in locations:
        if loc["type"] != "hawker": continue

        mdl.add_constraint(
            LUNCH_START * lunch_hawker_visit_var[(day, loc["name"])] <= u_var[(day, loc["name"])]
        )
        mdl.add_constraint(
            u_var[(day, loc["name"])] <= LUNCH_END + LARGE_M * (1 - lunch_hawker_visit_var[(day, loc["name"])])
        )

        mdl.add_constraint(
            DINNER_START * dinner_hawker_visit_var[(day, loc["name"])] <= u_var[(day, loc["name"])]
        )
        mdl.add_constraint(
            u_var[(day, loc["name"])] <= DINNER_END + LARGE_M * (1 - dinner_hawker_visit_var[(day, loc["name"])])
        )

for day in range(NUM_DAYS):
    # everyday, hotel must be starting point
    for loc in locations:
        if loc["name"] != locations[0]["name"]:
            mdl.add_constraint(
                u_var[(day, locations[0]["name"])] <= u_var[(day, loc["name"])]
            )

    # hotel starting must be at START_TIME earliest
    mdl.add_constraint(
        u_var[(day, locations[0]["name"])] >= START_TIME
    )

    for transport_type in transport_types:
        for source in locations:
            for dest in locations[1:]: # NOTE here that hotel (index 0) isn't included in destination. It will be computed later
                if source == dest: continue
                # every day, if the route is chosen, the time of finishing in this place is this
                for time_bracket in time_brackets:
                    transport_value = transport_matrix[(source["name"], dest["name"], time_bracket)][transport_type]
                    mdl.add_constraint(
                        u_var[(day, dest["name"])] >= u_var[(day, source["name"])] +
                        transport_value["duration"] + dest["duration"] -
                        LARGE_M * (1 - x_var[(day, transport_type, source["name"], dest["name"])]) -
                        LARGE_M * (1 - bracket_var[(day, source["name"], time_bracket)])
                    )

    # make sure to go back to hotel
    for loc in locations[1:]:
        mdl.add_constraint(
            sum([
                x_var[(day, transport_type, loc["name"], locations[0]["name"])]
                for transport_type in transport_types
            ]) == last_visit_var[(day, loc["name"])]
        )

    for loc in locations:
        mdl.add_constraint(
            sum([
                x_var[(day, transport_type, source["name"], loc["name"])]
                for transport_type in transport_types
                for source in locations
                if source != loc
            ]) == sum([
                x_var[(day, transport_type, loc["name"], dest["name"])]
                for transport_type in transport_types
                for dest in locations
                if dest != loc
            ])
        )

    # everyday, must go to hawkers at least twice (lunch & dinner)
    mdl.add_constraint(sum([
        x_var[(day, transport_type, source["name"], dest["name"])]
        for transport_type in transport_types
        for source in locations
        for dest in locations
        if source != dest and dest["type"] == "hawker"
    ]) >= 2)

    # every day, have lunch exactly once
    mdl.add_constraint(
        sum(lunch_hawker_visit_var[(day, hawker["name"])] for hawker in locations if hawker["type"] == "hawker") == 1
    )

    # every day, have dinner exactly once
    mdl.add_constraint(
        sum(dinner_hawker_visit_var[(day, hawker["name"])] for hawker in locations if hawker["type"] == "hawker") == 1
    )

    for source in locations:
        for dest in locations:
            if source == dest: continue
            # for every day, if public transportation is chosen, taxi can't be chosen, and vice versa
            mdl.add_constraint(
                sum([
                    x_var[(day, transport_type, source["name"], dest["name"])]
                    for transport_type in transport_types
                ]) <= 1
            )

mdl.add_constraint(cost_var ==
    NUM_DAYS * HOTEL_COST + 
    sum(
        x_var[(day, transport_type, source["name"], dest["name"])] * (
            transport_matrix[(source["name"], dest["name"], time_bracket)][transport_type]["price"] 
            + (dest["entrance_fee"] if dest["type"] == "attraction" else 0)
            + (dest["avg_food_price"] if dest["type"] == "hawker" else 0)
        )
        for day in range(NUM_DAYS)
        for transport_type in transport_types
        for source in locations
        for dest in locations
        for time_bracket in time_brackets
        if source["name"] != dest["name"]
    )
)
mdl.add_constraint(travel_time_var == 
    sum(
        x_var[(day, transport_type, source["name"], dest["name"])] * 
        transport_matrix[(source["name"], dest["name"], time_bracket)][transport_type]["duration"]
        for day in range(NUM_DAYS)
        for transport_type in transport_types
        for source in locations
        for dest in locations
        for time_bracket in time_brackets
        if source["name"] != dest["name"]
    )
)
mdl.add_constraint(satisfaction_var == 
    sum(
        x_var[(day, transport_type, source["name"], dest["name"])] * (
            dest["satisfaction"] if dest["type"] == "attraction" else 0
        )
        for day in range(NUM_DAYS)
        for transport_type in transport_types
        for source in locations
        for dest in locations
        if source["name"] != dest["name"]
    ) + sum(
        x_var[(day, transport_type, source["name"], dest["name"])] * (
            dest["rating"] if dest["type"] == "hawker" else 0
        )
        for day in range(NUM_DAYS)
        for transport_type in transport_types
        for source in locations
        for dest in locations
        if source["name"] != dest["name"]
    )
)
# finally, make sure everything is within budget
mdl.add_constraint(cost_var <= budget)

# you must visit 2-6 places per day
min_visits = NUM_DAYS * 2
max_visits = NUM_DAYS * 6
mdl.add_constraint(
    sum([
        x_var[(day, transport_type, source["name"], dest["name"])]
        for day in range(NUM_DAYS)
        for transport_type in transport_types
        for source in locations
        for dest in locations
        if source != dest
    ]) <= max_visits
)
mdl.add_constraint(
    sum([
        x_var[(day, transport_type, source["name"], dest["name"])]
        for day in range(NUM_DAYS)
        for transport_type in transport_types
        for source in locations
        for dest in locations
        if source != dest
    ]) >= min_visits
)

# <ADD CONSTRAINTS HERE>
constraints = [
    """mdl.add_constraint(x_var[(day, transport_type, source["name"], dest["name"])] == 1)"""
]

# %%
mdl.minimize(cost_var + travel_time_var * 0.1 - satisfaction_var * 80)

# %%
solution = mdl.solve(log_output=True)
print(solution)
# Out:
# Version identifier: 22.1.1.0 | 2022-11-28 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 1 time.
# MIP Presolve eliminated 2964 rows and 5 columns.
# MIP Presolve modified 84800 coefficients.
# Reduced MIP has 22208 rows, 5464 columns, and 119683 nonzeros.
# Reduced MIP has 5376 binaries, 87 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.09 sec. (99.75 ticks)
# Probing fixed 6 vars, tightened 0 bounds.
# Probing time = 0.04 sec. (30.97 ticks)
# Cover probing fixed 0 vars, tightened 12 bounds.
# Tried aggregator 2 times.
# Detecting symmetries...
# MIP Presolve eliminated 600 rows and 9 columns.
# Aggregator did 6 substitutions.
# Reduced MIP has 21602 rows, 5449 columns, and 117121 nonzeros.
# Reduced MIP has 5364 binaries, 84 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.06 sec. (97.76 ticks)
# Probing time = 0.01 sec. (6.89 ticks)
# Cover probing fixed 0 vars, tightened 3 bounds.
# Clique table members: 59398.
# Tightened 3 constraints.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 10 threads.
# Root relaxation solution time = 0.06 sec. (103.34 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
#       0     0    -4452.4306    40                  -4452.4306      377
#       0     0    -4426.4297    55                    Cuts: 17      591
#       0     0    -4426.4297    63                    Cuts: 61      643
#       0     0    -4426.4297    58                    Cuts: 11      659
#       0     0    -4426.4297    61                    Cuts: 19      694
# *     0+    0                           38.7120    -4426.4297              ---
# *     0+    0                         -158.9960    -4426.4297              ---
# *     0+    0                        -1252.3810    -4426.4297           253.44%
# *     0+    0                        -1992.2960    -4426.4297           122.18%
# *     0+    0                        -2896.1760    -4426.4297            52.84%
# *     0+    0                        -2933.7650    -4426.4297            50.88%
#       0     0  -1.00000e+75     0    -2933.7650    -4426.4297      694   50.88%
#       0     2    -4426.4297    41    -2933.7650    -4426.4297      694   50.88%
# Elapsed time = 1.76 sec. (3254.22 ticks, tree = 0.02 MB, solutions = 6)
# *    15+    3                        -3286.8570    -4426.4297            34.67%
#      42    36    -4415.9958    53    -3286.8570    -4426.4297     1771   34.67%
# *    53+    2                        -3615.7740    -4426.4297            22.42%
#     170   106    -4417.1642    40    -3615.7740    -4426.2480     4703   22.41%
#     256   234    -4422.5488    56    -3615.7740    -4426.2480     9086   22.41%
#     439   300    -4408.5367    47    -3615.7740    -4426.2480    12754   22.41%
#     638   451    -4376.9920    31    -3615.7740    -4426.2480    18850   22.41%
# *   777+  515                        -3639.0130    -4426.2480            21.63%
#     888   584    -4283.4810    33    -3639.0130    -4426.2480    26696   21.63%
#    1125   730    -4418.3929    50    -3639.0130    -4426.2480    36274   21.63%
#    1427   808    -4279.5771    48    -3639.0130    -4426.2480    41912   21.63%
#    1700  1054    -4422.0966    50    -3639.0130    -4426.2480    54571   21.63%
#    2360  1474    -4407.9020    36    -3639.0130    -4426.2480    81886   21.63%
# Elapsed time = 3.71 sec. (6365.77 ticks, tree = 22.01 MB, solutions = 17)
#    3215  2139    -4420.1466    52    -3639.0130    -4426.2480   102931   21.63%
#
# Performing restart 1
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 5492 rows and 1335 columns.
# MIP Presolve modified 8651 coefficients.
# Reduced MIP has 16110 rows, 4114 columns, and 84393 nonzeros.
# Reduced MIP has 4029 binaries, 84 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.04 sec. (86.11 ticks)
# Tried aggregator 1 time.
# MIP Presolve modified 624 coefficients.
# Reduced MIP has 16110 rows, 4114 columns, and 84393 nonzeros.
# Reduced MIP has 4029 binaries, 84 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.03 sec. (48.39 ticks)
# Represolve time = 0.15 sec. (231.19 ticks)
#    3664     0    -4425.0421    62    -3639.0130      Cuts: 30   110997   21.60%
#    3664     0    -4425.0421    64    -3639.0130      Cuts: 68   111095   21.60%
#    3664     0    -4425.0421    73    -3639.0130      Cuts: 45   111152   21.60%
# *  3664+    0                        -3656.2890    -4425.0421            21.03%
#    3664     0  -1.00000e+75     0    -3656.2890    -4425.0421   111152   21.03%
#    3664     0    -4425.0421    78    -3656.2890      Cuts: 30   111183   21.03%
#    3664     0    -4425.0421    76    -3656.2890      Cuts: 15   111204   21.03%
# *  3664+    0                        -3738.1010    -4425.0421            18.38%
#    3664     2    -4425.0421    75    -3738.1010    -4413.8372   111204   18.08%
# *  3673+    4                        -3939.7500    -4413.8372            12.03%
#    3690    18    -4069.4839    44    -3939.7500    -4413.8372   112040   12.03%
#    4020   257        cutoff          -3939.7500    -4413.8372   116725   12.03%
#    4523   634    -3987.0088    30    -3939.7500    -4413.8372   121031   12.03%
#    5249  1318    -4408.4522    49    -3939.7500    -4413.8372   126503   12.03%
#    5973  1892    -4388.4797    52    -3939.7500    -4413.8372   130914   12.03%
#    6948  2640    -4407.6362    55    -3939.7500    -4413.8372   134652   12.03%
#    8125  4039    -4389.8342    72    -3939.7500    -4413.8372   141710   12.03%
#    9458  4871    -4272.7823    37    -3939.7500    -4413.8372   146317   12.03%
# Elapsed time = 10.23 sec. (18729.06 ticks, tree = 17.83 MB, solutions = 21)
#   10922  6546    -4394.7620    43    -3939.7500    -4413.8372   155823   12.03%
#   12381  7846    -4405.4537    39    -3939.7500    -4413.8372   163903   12.03%
#   13704  9584    -4327.9042    41    -3939.7500    -4413.8372   171599   12.03%
#   15273 10780    -4403.5225    31    -3939.7500    -4413.8372   179667   12.03%
#   17026 12314    -4170.1141    49    -3939.7500    -4413.8372   185893   12.03%
#   18196 13834    -4408.9737    48    -3939.7500    -4413.8372   193805   12.03%
#   20577 15493    -4404.7250    47    -3939.7500    -4412.8938   202975   12.01%
# * 21067+15822                        -4231.4750    -4412.8938             4.29%
# * 22007+14675                        -4252.2390    -4412.8637             3.78%
#   22421 15450    -4412.6675    52    -4252.2390    -4412.8458   212533    3.78%
#   24498 16437    -4407.6837    48    -4252.2390    -4412.8458   221943    3.78%
# * 26618+18207                        -4375.3100    -4412.7276             0.86%
#   26929 19390    -4412.6737    66    -4375.3100    -4412.7018   233668    0.85%
# Elapsed time = 15.68 sec. (28272.69 ticks, tree = 70.81 MB, solutions = 26)
#   29756 13295    -4392.3273    33    -4375.3100    -4412.6998   240735    0.85%
# * 30732+14902                        -4375.5040    -4412.6998             0.85%
#   31529 15629    -4411.7001    48    -4375.5040    -4412.6998   251737    0.85%
#   34426 18344    -4404.2908    35    -4375.5040    -4412.6987   262951    0.85%
#   36911 20190    -4412.6751    54    -4375.5040    -4412.6970   271210    0.85%
# * 38626+21476                        -4379.9870    -4412.6958             0.75%
# * 39035+22199                        -4380.0490    -4412.6952             0.75%
# * 39090+22199                        -4380.2670    -4412.6952             0.74%
#   39186 21422    -4412.6386    37    -4380.2670    -4412.6952   283390    0.74%
# * 39902+21907                        -4384.8180    -4412.6946             0.64%
#   40644 23060    -4412.6896    65    -4384.8180    -4412.6946   292118    0.64%
#   42361 22826    -4404.0173    75    -4384.8180    -4412.6946   296341    0.64%
#
# Performing restart 2
#
# Repeating presolve.
# Tried aggregator 2 times.
# MIP Presolve eliminated 12122 rows and 3025 columns.
# MIP Presolve modified 10901 coefficients.
# Aggregator did 39 substitutions.
# Reduced MIP has 3949 rows, 1050 columns, and 23529 nonzeros.
# Reduced MIP has 974 binaries, 75 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.04 sec. (115.38 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 3949 rows, 1050 columns, and 23529 nonzeros.
# Reduced MIP has 974 binaries, 75 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (13.72 ticks)
# Represolve time = 0.09 sec. (156.52 ticks)
#   42567     0    -4413.3328    63    -4384.8180      Cuts: 29   305942    0.64%
#   42567     0    -4413.3328    63    -4384.8180      Cuts: 17   305962    0.64%
#   42567     0    -4413.3328    84    -4384.8180      Cuts: 36   306001    0.64%
#   42567     0    -4413.3328    72    -4384.8180       Cuts: 6   306013    0.64%
#   42567     0    -4413.3328    76    -4384.8180      Cuts: 69   306046    0.64%
#   42567     0    -4413.3328    78    -4384.8180       Cuts: 3   306055    0.64%
#   42567     0    -4413.3328    65    -4384.8180      Cuts: 22   306081    0.64%
#   42567     0    -4413.3328    77    -4384.8180     Cuts: 155   306120    0.64%
#
# Repeating presolve.
# Tried aggregator 1 time.
# MIP Presolve eliminated 107 rows and 29 columns.
# MIP Presolve modified 145 coefficients.
# Reduced MIP has 3842 rows, 1021 columns, and 23375 nonzeros.
# Reduced MIP has 945 binaries, 75 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (15.76 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 3842 rows, 1021 columns, and 23375 nonzeros.
# Reduced MIP has 945 binaries, 75 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (13.57 ticks)
# Represolve time = 0.04 sec. (55.57 ticks)
#   42567     0    -4413.2361    78    -4384.8180      Cuts: 25   306598    0.64%
#   42567     0    -4413.2361    83    -4384.8180      Cuts: 79   306644    0.64%
#   42567     0    -4413.2361    88    -4384.8180      Cuts: 42   306668    0.64%
#   42567     0    -4413.2361    81    -4384.8180      Cuts: 24   306705    0.64%
#   42567     0    -4413.2361   100    -4384.8180      Cuts: 56   306773    0.64%
#   42567     0    -4413.2361    87    -4384.8180       Cuts: 5   306785    0.64%
#   42567     0    -4413.2361    79    -4384.8180      Cuts: 65   306826    0.64%
#   42567     0    -4413.2361    85    -4384.8180      Cuts: 27   306876    0.64%
#   42567     0    -4413.2361    93    -4384.8180      Cuts: 48   306912    0.64%
#   42567     0    -4413.2361    88    -4384.8180      Cuts: 10   306920    0.64%
#   42567     2    -4413.2361    88    -4384.8180    -4412.6932   306920    0.64%
#   43172   169    -4410.4620    34    -4384.8180    -4412.6932   311349    0.64%
#   45076  1307    -4407.9850    41    -4384.8180    -4412.6932   325656    0.64%
# Elapsed time = 22.34 sec. (40646.60 ticks, tree = 1.36 MB, solutions = 46)
#   49172  4274    -4408.7074    61    -4384.8180    -4412.6746   350091    0.64%
#   55197  9459    -4412.2026    32    -4384.8180    -4412.5740   394264    0.63%
#   61829 14706    -4404.4014    63    -4384.8180    -4412.5740   437563    0.63%
#   67509 19180    -4408.7136    36    -4384.8180    -4412.5740   490833    0.63%
#   73354 23370    -4410.4761    58    -4384.8180    -4412.5740   537463    0.63%
#   79451 28529    -4411.5657    62    -4384.8180    -4412.5740   597975    0.63%
# * 82726+30885                        -4387.4430    -4412.5740             0.57%
#   85758 32437    -4412.2498    73    -4387.4430    -4412.5740   644740    0.57%
#   91117 37466    -4412.5740    36    -4387.4430    -4412.5740   694837    0.57%
#   96119 40985    -4412.1045    56    -4387.4430    -4412.5740   733822    0.57%
#  101409 46038    -4409.5439    58    -4387.4430    -4412.5740   789517    0.57%
# Elapsed time = 28.59 sec. (50184.70 ticks, tree = 48.46 MB, solutions = 47)
#  107072 50667    -4399.3808    35    -4387.4430    -4412.5740   840610    0.57%
#  112639 54820    -4412.3684    67    -4387.4430    -4412.5603   884281    0.57%
#  118109 59436    -4411.0050    49    -4387.4430    -4412.5223   935438    0.57%
#  122796 62788    -4400.9550    60    -4387.4430    -4412.4807   976120    0.57%
#  127333 67047    -4407.5216    44    -4387.4430    -4412.4222  1033558    0.57%
#  132225 70954    -4411.4973    55    -4387.4430    -4412.3251  1084526    0.57%
#  137393 74581    -4399.8845    45    -4387.4430    -4412.2110  1129572    0.56%
#  142681 78546    -4412.0250    43    -4387.4430    -4412.2040  1184426    0.56%
#  147922 82456    -4408.5352    58    -4387.4430    -4412.2040  1230360    0.56%
#  152764 87448    -4411.8820    72    -4387.4430    -4412.2040  1299271    0.56%
# Elapsed time = 34.79 sec. (59723.34 ticks, tree = 93.53 MB, solutions = 47)
#  157721 90199    -4405.5761    81    -4387.4430    -4412.2040  1340348    0.56%
#  162483 94177    -4409.1146    58    -4387.4430    -4412.2040  1406178    0.56%
#  167368 98179    -4405.0321    52    -4387.4430    -4412.2040  1470593    0.56%
#  171920 101593    -4401.4156    56    -4387.4430    -4412.2040  1531191    0.56%
#  176810 105428    -4410.9133    70    -4387.4430    -4412.2040  1595082    0.56%
#  181785 109411    -4410.5894    47    -4387.4430    -4412.2040  1660992    0.56%
#  186606 113975    -4400.7529    37    -4387.4430    -4412.2040  1732631    0.56%
#  191696 117289        cutoff          -4387.4430    -4412.1978  1784935    0.56%
#  195855 121201    -4410.9796    58    -4387.4430    -4412.1808  1859990    0.56%
#  200279 124225    infeasible          -4387.4430    -4412.1479  1927177    0.56%
# Elapsed time = 40.97 sec. (69262.22 ticks, tree = 131.35 MB, solutions = 47)
#  204163 126067    -4408.0115    49    -4387.4430    -4412.1346  1978407    0.56%
#  208415 128098    -4397.9903    45    -4387.4430    -4412.1100  2031202    0.56%
#  212500 130997    -4407.6707    80    -4387.4430    -4412.0672  2111304    0.56%
#  216537 133613    -4408.2465    31    -4387.4430    -4412.0254  2194499    0.56%
#  220925 135966    -4411.9164    63    -4387.4430    -4411.9922  2249318    0.56%
#  225681 139717    -4411.5480    55    -4387.4430    -4411.9580  2307979    0.56%
#  230459 144028    -4408.5220    24    -4387.4430    -4411.9580  2371446    0.56%
#  235378 146931    -4400.7940    38    -4387.4430    -4411.9580  2418592    0.56%
#  240027 150582    -4411.6242    62    -4387.4430    -4411.9580  2479239    0.56%
#  245039 154951        cutoff          -4387.4430    -4411.9580  2551790    0.56%
# Elapsed time = 47.29 sec. (78800.64 ticks, tree = 166.15 MB, solutions = 47)
#  249668 158711    -4411.9580    42    -4387.4430    -4411.9580  2614732    0.56%
#  254375 162417    -4410.7165    50    -4387.4430    -4411.9580  2674865    0.56%
#  258786 166566    -4405.7920    28    -4387.4430    -4411.9580  2743905    0.56%
#  262703 169759    -4405.4167    63    -4387.4430    -4411.9580  2799363    0.56%
#  266759 173789    -4410.8895    49    -4387.4430    -4411.9580  2880447    0.56%
#  270814 176679        cutoff          -4387.4430    -4411.9580  2938394    0.56%
#  275116 179812    -4410.3111    54    -4387.4430    -4411.9580  3011465    0.56%
#  279095 182460    -4393.4005    52    -4387.4430    -4411.9563  3081647    0.56%
#  283426 185018    infeasible          -4387.4430    -4411.9480  3148297    0.56%
#  287544 187396    -4410.5087    37    -4387.4430    -4411.9341  3219611    0.56%
# Elapsed time = 53.58 sec. (88339.82 ticks, tree = 201.77 MB, solutions = 47)
#  291567 189303    -4408.1933    60    -4387.4430    -4411.9088  3284424    0.56%
#  295416 191331    -4395.1253    54    -4387.4430    -4411.8761  3349364    0.56%
#  299129 193871    -4404.6784    66    -4387.4430    -4411.8332  3452475    0.56%
#  302412 194797        cutoff          -4387.4430    -4411.8014  3503447    0.56%
#  306416 196868    infeasible          -4387.4430    -4411.7714  3582519    0.55%
#  310691 198901    -4410.3415    50    -4387.4430    -4411.7397  3650711    0.55%
#  314950 201032    -4411.1069    59    -4387.4430    -4411.6989  3728599    0.55%
#  318963 203636    -4396.8844    58    -4387.4430    -4411.6555  3807534    0.55%
#  323139 205843    -4405.9708    55    -4387.4430    -4411.5932  3867506    0.55%
#  339393 218420    -4396.2712    50    -4387.4430    -4411.5880  4148990    0.55%
# Elapsed time = 61.83 sec. (100738.80 ticks, tree = 236.48 MB, solutions = 47)
#  353693 227550    -4406.2174    60    -4387.4430    -4411.5880  4433943    0.55%
#  368090 233916    infeasible          -4387.4430    -4411.5031  4755860    0.55%
#  383180 241054    -4401.2096    40    -4387.4430    -4411.3663  5091405    0.55%
# *390630+244861                        -4391.0410    -4411.3030             0.46%
#  398520 244184    -4409.8715    61    -4391.0410    -4411.3030  5384016    0.46%
#  410630 249675    -4403.3812    63    -4391.0410    -4411.1533  5692525    0.46%
#  424940 256501    -4406.7647    42    -4391.0410    -4411.0700  6037941    0.46%
#  439425 265891    -4399.8812    33    -4391.0410    -4411.0220  6311395    0.46%
#  452967 271259    -4401.6535    46    -4391.0410    -4410.9999  6628921    0.45%
#  467195 276766    -4398.6944    29    -4391.0410    -4410.8679  6986575    0.45%
#  480308 281431    -4405.8020    62    -4391.0410    -4410.7440  7407607    0.45%
# Elapsed time = 87.14 sec. (138889.41 ticks, tree = 310.23 MB, solutions = 48)
#  493587 285913    -4399.3281    85    -4391.0410    -4410.6520  7738362    0.45%
#  508016 292047    -4404.2520    25    -4391.0410    -4410.5395  8146298    0.44%
#  525515 301903    -4397.3290    46    -4391.0410    -4410.4463  8430548    0.44%
#  539730 308520        cutoff          -4391.0410    -4410.3332  8822054    0.44%
#  554310 314318    -4399.5495    71    -4391.0410    -4410.2389  9142598    0.44%
# *561037+317502                        -4394.6920    -4410.1917             0.35%
#  569924 304776    -4408.4797    56    -4394.6920    -4410.1295  9462025    0.35%
#  585075 310351    -4404.4266    56    -4394.6920    -4409.9829  9808921    0.35%
#  600016 315063    -4406.1698    62    -4394.6920    -4409.7431 10170802    0.34%
#  616128 316440    -4405.2873    69    -4394.6920    -4409.6366 10515236    0.34%
#  628738 316283    infeasible          -4394.6920    -4409.4891 10918611    0.34%
# Elapsed time = 111.95 sec. (177039.17 ticks, tree = 349.38 MB, solutions = 49)
#  642520 318848        cutoff          -4394.6920    -4409.3835 11302527    0.33%
#  656762 320072    -4400.9886    55    -4394.6920    -4409.2687 11639647    0.33%
#  673031 325718    -4399.5736    59    -4394.6920    -4409.1546 11962825    0.33%
#  689692 328455    -4399.6637    58    -4394.6920    -4409.0363 12302207    0.33%
#  706010 335461    -4408.0515    71    -4394.6920    -4408.9077 12562985    0.32%
#  721200 338344    -4402.4499    43    -4394.6920    -4408.7558 12928378    0.32%
# *731697+342623                        -4394.7440    -4408.7028             0.32%
#  737028 345184    -4406.3570    45    -4394.7440    -4408.6475 13241840    0.32%
#  752060 351314    -4397.3820    26    -4394.7440    -4408.5401 13604170    0.31%
# *761679+354863                        -4395.2250    -4408.4931             0.30%
#  768200 352246    -4397.8580    22    -4395.2250    -4408.4344 13867110    0.30%
#  783242 358412        cutoff          -4395.2250    -4408.2895 14205258    0.30%
# Elapsed time = 136.37 sec. (215189.86 ticks, tree = 400.24 MB, solutions = 51)
#  798917 362134        cutoff          -4395.2250    -4408.1766 14505208    0.29%
#  814301 367527    -4395.3380    24    -4395.2250    -4408.0564 14859468    0.29%
#  829101 371431    -4407.7317    47    -4395.2250    -4407.9203 15183597    0.29%
#  843845 374320    -4407.6204    57    -4395.2250    -4407.7982 15516020    0.29%
#  860237 378673        cutoff          -4395.2250    -4407.7012 15834385    0.28%
#  876312 384740    -4399.7000    33    -4395.2250    -4407.5677 16156969    0.28%
#  891742 388432    -4398.5889    22    -4395.2250    -4407.4395 16438175    0.28%
#  907005 392941    -4405.6927    47    -4395.2250    -4407.3424 16769118    0.28%
#  922647 397465    -4399.1811    47    -4395.2250    -4407.1918 17081270    0.27%
#  939566 403000        cutoff          -4395.2250    -4407.1079 17368841    0.27%
# Elapsed time = 160.47 sec. (253338.86 ticks, tree = 454.72 MB, solutions = 51)
#  953908 405286        cutoff          -4395.2250    -4406.9840 17695764    0.27%
#  969134 407972    -4399.3625    47    -4395.2250    -4406.9183 18083571    0.27%
#  985044 412262    -4405.0414    47    -4395.2250    -4406.8199 18373857    0.26%
#  1000445 417066        cutoff          -4395.2250    -4406.6799 18718289    0.26%
#  1016320 421070    -4399.0930    38    -4395.2250    -4406.5910 19014979    0.26%
#  1031453 424284    -4406.2610    61    -4395.2250    -4406.4842 19341455    0.26%
#  1046496 426001    -4397.0460    17    -4395.2250    -4406.3769 19674552    0.25%
#  1061569 428508    -4405.6571    37    -4395.2250    -4406.3041 19960061    0.25%
#  1078686 433454        cutoff          -4395.2250    -4406.1930 20209370    0.25%
#  1096484 438893    -4395.9797    71    -4395.2250    -4406.0985 20479865    0.25%
# Elapsed time = 183.88 sec. (291488.08 ticks, tree = 496.02 MB, solutions = 51)
#  1113551 442314        cutoff          -4395.2250    -4405.9760 20755544    0.24%
#  1131443 446667        cutoff          -4395.2250    -4405.8678 20956807    0.24%
#  1148643 451596    -4404.6589    57    -4395.2250    -4405.7391 21186156    0.24%
#  1164861 455043    -4395.5450    30    -4395.2250    -4405.6282 21474242    0.24%
#  1181605 458406    -4400.8278    58    -4395.2250    -4405.5228 21696087    0.23%
#  1197437 460896    -4402.7968    37    -4395.2250    -4405.4086 21984279    0.23%
#  1213483 463887    -4398.2030    26    -4395.2250    -4405.3460 22262821    0.23%
#  1230217 468332    -4398.0012    29    -4395.2250    -4405.2491 22505534    0.23%
#  1247224 471764        cutoff          -4395.2250    -4405.2152 22721250    0.23%
#  1262895 474258        cutoff          -4395.2250    -4405.1068 22953230    0.22%
# Elapsed time = 205.98 sec. (329638.22 ticks, tree = 542.19 MB, solutions = 51)
#  1277710 476054    -4398.4972    72    -4395.2250    -4404.9936 23298772    0.22%
#  1293940 478839        cutoff          -4395.2250    -4404.8948 23550468    0.22%
#  1310248 479744        cutoff          -4395.2250    -4404.7902 23842615    0.22%
#  1324911 478022    -4397.6851    40    -4395.2250    -4404.7005 24143368    0.22%
#  1341106 476126    -4397.4397    33    -4395.2250    -4404.6378 24405189    0.21%
#  1356331 472594    -4396.6032    42    -4395.2250    -4404.5243 24818387    0.21%
#  1371860 466764    -4396.6791    40    -4395.2250    -4404.4501 25167755    0.21%
#  1385978 465495        cutoff          -4395.2250    -4404.3835 25467549    0.21%
#  1399452 463560    -4395.2850    19    -4395.2250    -4404.3021 25784622    0.21%
#  1414854 461877    -4400.5924    62    -4395.2250    -4404.2252 26028859    0.20%
# Elapsed time = 229.70 sec. (367788.00 ticks, tree = 571.52 MB, solutions = 51)
#  1429412 463159        cutoff          -4395.2250    -4404.1696 26334417    0.20%
#  1445533 463715        cutoff          -4395.2250    -4404.0698 26623337    0.20%
#  1459907 463458    -4397.6936    28    -4395.2250    -4403.9730 26882921    0.20%
#  1473953 461721        cutoff          -4395.2250    -4403.8618 27191508    0.20%
#  1488711 461364    -4403.5058    52    -4395.2250    -4403.7950 27419371    0.19%
#  1503852 461645        cutoff          -4395.2250    -4403.6900 27685843    0.19%
#  1517780 458970    -4402.7287    59    -4395.2250    -4403.6097 28062906    0.19%
#  1531495 457504    -4395.7550    27    -4395.2250    -4403.5209 28244175    0.19%
#  1547870 456952    -4397.7555    55    -4395.2250    -4403.4344 28535098    0.19%
#  1562154 456803    -4398.5550    67    -4395.2250    -4403.3384 28783470    0.18%
# Elapsed time = 252.31 sec. (405938.28 ticks, tree = 566.38 MB, solutions = 51)
#  1579488 457922    -4399.3454    64    -4395.2250    -4403.2157 29020367    0.18%
#  1594415 457624    -4396.5772    45    -4395.2250    -4403.1149 29261112    0.18%
#  1611785 457915    -4399.2426    42    -4395.2250    -4402.9973 29516135    0.18%
#  1626981 458230    -4402.4135    38    -4395.2250    -4402.9143 29773456    0.17%
#  1643713 459774    -4397.7384    53    -4395.2250    -4402.7906 29948148    0.17%
#  1660501 460375    -4399.4558    52    -4395.2250    -4402.6871 30141373    0.17%
#  1675795 461539    -4401.1295    56    -4395.2250    -4402.6156 30369276    0.17%
#  1692272 459699        cutoff          -4395.2250    -4402.5011 30567143    0.17%
#  1706479 459415    -4399.5305    75    -4395.2250    -4402.4160 30810561    0.16%
#  1723195 457969    -4402.1202    60    -4395.2250    -4402.3507 31151407    0.16%
# Elapsed time = 274.12 sec. (444087.70 ticks, tree = 567.80 MB, solutions = 51)
#  1737944 457400    -4399.0306    38    -4395.2250    -4402.2622 31325354    0.16%
#  1755258 456727    -4399.8470    43    -4395.2250    -4402.1578 31544912    0.16%
#  1770747 459426    -4396.5750    43    -4395.2250    -4402.0578 31792966    0.16%
#  1787772 460101        cutoff          -4395.2250    -4401.9556 31993482    0.15%
#  1805250 461367    -4398.4450    64    -4395.2250    -4401.8699 32164412    0.15%
#  1820289 462577        cutoff          -4395.2250    -4401.7759 32394454    0.15%
#  1838110 463705    -4401.3728    49    -4395.2250    -4401.6861 32554823    0.15%
#  1852977 465476    -4401.0759    64    -4395.2250    -4401.6107 32764761    0.15%
#  1870445 467149    -4398.5330    32    -4395.2250    -4401.5065 32944447    0.14%
#  1887696 470141    -4401.2794    45    -4395.2250    -4401.4272 33124500    0.14%
# Elapsed time = 295.58 sec. (482236.28 ticks, tree = 580.87 MB, solutions = 51)
#  1902197 473566        cutoff          -4395.2250    -4401.3848 33297716    0.14%
#  1919169 476602        cutoff          -4395.2250    -4401.3264 33532805    0.14%
#  1935557 478027    -4399.5032    29    -4395.2250    -4401.2674 33664370    0.14%
#  1951004 481552        cutoff          -4395.2250    -4401.1985 33841169    0.14%
#  1968208 486651        cutoff          -4395.2250    -4401.1422 34025397    0.13%
#  1984887 488858    -4399.3458    55    -4395.2250    -4401.0996 34248396    0.13%
#  1998886 492151    -4400.5531    52    -4395.2250    -4401.0508 34438380    0.13%
#  2015801 494976    -4398.4110    43    -4395.2250    -4400.9938 34600244    0.13%
#  2033456 497986    -4399.2759    42    -4395.2250    -4400.9464 34745418    0.13%
#  2047156 500834    -4399.4315    45    -4395.2250    -4400.8946 34953270    0.13%
# Elapsed time = 316.65 sec. (520386.62 ticks, tree = 615.58 MB, solutions = 51)
#  2064681 502959    -4398.9145    46    -4395.2250    -4400.8479 35176008    0.13%
#  2079852 503760        cutoff          -4395.2250    -4400.8042 35316826    0.13%
#  2094682 504389        cutoff          -4395.2250    -4400.7588 35498477    0.13%
#  2111326 507385    infeasible          -4395.2250    -4400.6987 35670042    0.12%
#  2124262 509753    -4397.4496    50    -4395.2250    -4400.6510 35843336    0.12%
#  2141367 512846        cutoff          -4395.2250    -4400.6063 36043040    0.12%
#  2157699 515038    -4400.4837    41    -4395.2250    -4400.5614 36255686    0.12%
#  2171494 513548        cutoff          -4395.2250    -4400.5265 36387014    0.12%
#  2187959 515162        cutoff          -4395.2250    -4400.4864 36578159    0.12%
#  2204128 517925    -4397.5204    44    -4395.2250    -4400.4669 36806440    0.12%
# Elapsed time = 337.83 sec. (558536.26 ticks, tree = 635.02 MB, solutions = 51)
#  2218401 519270        cutoff          -4395.2250    -4400.4199 36935703    0.12%
#  2234606 521326    -4398.3334    38    -4395.2250    -4400.3744 37132278    0.12%
#  2250599 523063        cutoff          -4395.2250    -4400.3332 37287162    0.12%
#  2263692 524618    -4395.2661    36    -4395.2250    -4400.2973 37455740    0.12%
#  2280195 526993        cutoff          -4395.2250    -4400.2600 37611986    0.11%
#  2295949 530544    -4400.0736    39    -4395.2250    -4400.2204 37833128    0.11%
#  2309421 532605    -4400.0683    79    -4395.2250    -4400.1903 38026823    0.11%
#  2325279 533879    -4399.9082    53    -4395.2250    -4400.1580 38165829    0.11%
#  2341574 535317    -4398.1810    25    -4395.2250    -4400.1260 38318619    0.11%
#  2354858 537100        cutoff          -4395.2250    -4400.0920 38517797    0.11%
# Elapsed time = 358.94 sec. (596685.86 ticks, tree = 657.32 MB, solutions = 51)
#  2370411 538644    -4399.1448    45    -4395.2250    -4400.0506 38661956    0.11%
#  2386452 540884    -4399.7570    44    -4395.2250    -4400.0120 38841217    0.11%
#  2399302 543040    infeasible          -4395.2250    -4399.9803 39040195    0.11%
#  2414312 545137        cutoff          -4395.2250    -4399.9470 39232662    0.11%
#  2430773 546898    -4398.0240    25    -4395.2250    -4399.9137 39377024    0.11%
#  2444558 549000    -4397.5832    54    -4395.2250    -4399.8829 39555246    0.11%
#  2459159 549646    -4396.6692    35    -4395.2250    -4399.8539 39748702    0.11%
#  2474921 550793    -4397.4343    68    -4395.2250    -4399.8207 39870148    0.10%
#  2487879 552570    -4399.5658    36    -4395.2250    -4399.7903 40063445    0.10%
#  2501915 553426        cutoff          -4395.2250    -4399.7560 40286135    0.10%
# Elapsed time = 380.46 sec. (634834.36 ticks, tree = 676.86 MB, solutions = 51)
#  2517717 554053        cutoff          -4395.2250    -4399.7250 40476515    0.10%
#  2529600 554269    infeasible          -4395.2250    -4399.6941 40620242    0.10%
#  2544817 554273    -4396.9378    36    -4395.2250    -4399.6706 40752846    0.10%
#  2560236 555367    -4399.3896    55    -4395.2250    -4399.6370 40947923    0.10%
#  2573030 556994    -4397.1346    49    -4395.2250    -4399.6060 41113797    0.10%
#  2589042 558370    -4395.5338    40    -4395.2250    -4399.5753 41312273    0.10%
#  2603052 558785    -4399.0053    50    -4395.2250    -4399.5472 41460692    0.10%
#  2616720 558129    -4398.6665    44    -4395.2250    -4399.5223 41639141    0.10%
#  2632740 559099    -4397.8102    35    -4395.2250    -4399.4910 41897753    0.10%
#  2644817 559307    -4397.1392    31    -4395.2250    -4399.4577 42046789    0.10%
# Elapsed time = 401.68 sec. (672983.49 ticks, tree = 684.28 MB, solutions = 51)
#  2660762 560817        cutoff          -4395.2250    -4399.4307 42251733    0.10%
#  2676605 561784        cutoff          -4395.2250    -4399.4015 42410576    0.10%
#  2688232 561939    -4399.0398    38    -4395.2250    -4399.3740 42602541    0.09%
#  2703989 561844    -4398.4914    52    -4395.2250    -4399.3487 42727864    0.09%
#  2718849 562658        cutoff          -4395.2250    -4399.3188 42959414    0.09%
#  2730479 562381        cutoff          -4395.2250    -4399.2939 43107570    0.09%
#  2745941 562553    -4398.6699    42    -4395.2250    -4399.2653 43221037    0.09%
#  2758912 563297        cutoff          -4395.2250    -4399.2359 43472797    0.09%
#  2772672 563567    -4397.3270    65    -4395.2250    -4399.2107 43575369    0.09%
#  2787881 564066    infeasible          -4395.2250    -4399.1859 43768910    0.09%
# Elapsed time = 423.13 sec. (711133.09 ticks, tree = 690.57 MB, solutions = 51)
#  2800466 565100    -4397.8891    48    -4395.2250    -4399.1593 43939098    0.09%
#  2814244 564577    -4398.4153    42    -4395.2250    -4399.1396 44168583    0.09%
#  2829304 564418    -4397.7345    37    -4395.2250    -4399.1130 44310642    0.09%
#  2841515 563451    -4395.4979    40    -4395.2250    -4399.0922 44505731    0.09%
#  2856244 562841    -4398.9083    55    -4395.2250    -4399.0811 44628977    0.09%
#  2871802 562464    -4398.8990    37    -4395.2250    -4399.0529 44834781    0.09%
#  2883595 561838    -4398.0525    53    -4395.2250    -4399.0245 45039746    0.09%
#  2898985 561344    -4395.9589    36    -4395.2250    -4399.0015 45143622    0.09%
#  2913994 560801    infeasible          -4395.2250    -4398.9733 45346102    0.09%
#  2925981 559060    -4396.6910    48    -4395.2250    -4398.9465 45537785    0.08%
# Elapsed time = 445.29 sec. (749282.70 ticks, tree = 685.13 MB, solutions = 51)
#  2941714 558316        cutoff          -4395.2250    -4398.9222 45763971    0.08%
#  2956359 558679    -4397.7601    45    -4395.2250    -4398.8946 45936392    0.08%
#  2969276 557881    -4395.8420    21    -4395.2250    -4398.8642 46067953    0.08%
#  2984383 556324    infeasible          -4395.2250    -4398.8392 46221886    0.08%
#  2997348 553466    -4397.2280    41    -4395.2250    -4398.8171 46472485    0.08%
#  3011853 551671    -4398.0850    42    -4395.2250    -4398.7934 46613389    0.08%
#  3026833 550005    -4398.6918    70    -4395.2250    -4398.7736 46837877    0.08%
#  3038801 549031    -4398.4396    39    -4395.2250    -4398.7540 46976429    0.08%
#  3054157 547333        cutoff          -4395.2250    -4398.7261 47134376    0.08%
#  3067873 545980    -4397.5691    49    -4395.2250    -4398.7010 47325317    0.08%
# Elapsed time = 469.54 sec. (787431.65 ticks, tree = 670.49 MB, solutions = 51)
#  3080797 544690    -4397.0896    61    -4395.2250    -4398.6730 47469114    0.08%
#  3096341 543469    infeasible          -4395.2250    -4398.6507 47640551    0.08%
#  3108857 540858    infeasible          -4395.2250    -4398.6241 47901052    0.08%
#  3122438 539071    -4397.1297    58    -4395.2250    -4398.5986 48005670    0.08%
#  3137410 537874        cutoff          -4395.2250    -4398.5780 48145477    0.08%
#  3148810 534759    -4398.3329    37    -4395.2250    -4398.5501 48393040    0.08%
#  3163822 533200    -4396.8741    51    -4395.2250    -4398.5227 48545903    0.08%
#  3178157 531596    -4397.7501    58    -4395.2250    -4398.4982 48772016    0.07%
#  3190609 530517    -4397.4319    29    -4395.2250    -4398.4727 48846546    0.07%
#  3205692 527682        cutoff          -4395.2250    -4398.4489 49031709    0.07%
# Elapsed time = 490.58 sec. (825580.99 ticks, tree = 649.17 MB, solutions = 51)
#  3218592 525916        cutoff          -4395.2250    -4398.4247 49228346    0.07%
#  3232055 523421    -4397.8092    27    -4395.2250    -4398.3998 49378002    0.07%
#  3246924 520832    infeasible          -4395.2250    -4398.3780 49580309    0.07%
#  3258918 518971    -4398.2338    42    -4395.2250    -4398.3527 49722475    0.07%
#  3273060 515479    -4398.1862    36    -4395.2250    -4398.3296 49936611    0.07%
#  3287537 514084    -4397.0942    43    -4395.2250    -4398.3047 50054214    0.07%
#  3299017 511792    -4395.2970    19    -4395.2250    -4398.2790 50212612    0.07%
#  3314015 508487    -4397.2463    35    -4395.2250    -4398.2522 50414028    0.07%
#  3327346 506115        cutoff          -4395.2250    -4398.2340 50614175    0.07%
#  3339932 503121    -4398.1260    34    -4395.2250    -4398.2072 50778177    0.07%
# Elapsed time = 512.36 sec. (863730.49 ticks, tree = 621.09 MB, solutions = 51)
#  3355656 501321        cutoff          -4395.2250    -4398.1863 50912379    0.07%
#  3368059 498485        cutoff          -4395.2250    -4398.1643 51110180    0.07%
#  3382207 495155    -4397.9923    44    -4395.2250    -4398.1401 51269326    0.07%
#  3397413 492722        cutoff          -4395.2250    -4398.1186 51441779    0.07%
#  3409164 490270    infeasible          -4395.2250    -4398.0969 51581669    0.07%
#  3423934 486606    infeasible          -4395.2250    -4398.0692 51768133    0.06%
#  3438230 483745    infeasible          -4395.2250    -4398.0483 52019525    0.06%
#  3450670 480763    infeasible          -4395.2250    -4398.0242 52162646    0.06%
#  3466228 475721        cutoff          -4395.2250    -4397.9976 52411182    0.06%
#  3479722 472412        cutoff          -4395.2250    -4397.9762 52683662    0.06%
# Elapsed time = 534.16 sec. (901880.19 ticks, tree = 585.48 MB, solutions = 51)
#  3491839 470200    -4397.7823    38    -4395.2250    -4397.9518 52766897    0.06%
#  3507373 466369        cutoff          -4395.2250    -4397.9233 52934310    0.06%
#  3519707 461746        cutoff          -4395.2250    -4397.9017 53224400    0.06%
#  3532787 457299        cutoff          -4395.2250    -4397.8750 53414916    0.06%
#  3548889 452227    -4396.4732    31    -4395.2250    -4397.8542 53639433    0.06%
#  3561005 449957        cutoff          -4395.2250    -4397.8330 53737693    0.06%
#  3574486 444658    infeasible          -4395.2250    -4397.8068 53967225    0.06%
#  3589703 437358    infeasible          -4395.2250    -4397.7840 54229223    0.06%
#  3601293 432726    -4395.8160    14    -4395.2250    -4397.7597 54373499    0.06%
#  3615772 427470    -4397.5645    43    -4395.2250    -4397.7300 54614324    0.06%
# Elapsed time = 556.84 sec. (940029.43 ticks, tree = 532.51 MB, solutions = 51)
#  3630138 425050        cutoff          -4395.2250    -4397.7044 54711323    0.06%
#  3641606 418381    -4397.5440    20    -4395.2250    -4397.6777 54932414    0.06%
#  3656835 412875        cutoff          -4395.2250    -4397.6421 55116821    0.05%
#  3671139 409476    -4395.2960    19    -4395.2250    -4397.6180 55359898    0.05%
#  3683260 405883    -4397.3616    52    -4395.2250    -4397.5876 55499280    0.05%
#  3698745 401666    -4397.4630    22    -4395.2250    -4397.5569 55706916    0.05%
#  3711689 400129    infeasible          -4395.2250    -4397.5320 55835714    0.05%
#  3723878 395423        cutoff          -4395.2250    -4397.5068 56072776    0.05%
#  3739629 390675    -4395.9220    27    -4395.2250    -4397.4780 56246211    0.05%
#  3752170 383678    infeasible          -4395.2250    -4397.4579 56468694    0.05%
# Elapsed time = 578.34 sec. (978178.21 ticks, tree = 480.19 MB, solutions = 51)
#  3764320 379339        cutoff          -4395.2250    -4397.4368 56615519    0.05%
#  3779887 372433    -4395.9960    21    -4395.2250    -4397.4105 56836053    0.05%
#  3792680 366621    -4396.9350    22    -4395.2250    -4397.3902 57016670    0.05%
#  3804663 362030    -4397.1696    46    -4395.2250    -4397.3634 57147248    0.05%
#  3820173 356847    -4397.1144    64    -4395.2250    -4397.3279 57360056    0.05%
#  3832690 351320        cutoff          -4395.2250    -4397.2994 57553808    0.05%
#  3844941 346613    infeasible          -4395.2250    -4397.2660 57672004    0.05%
#  3860583 341529    -4395.7730    21    -4395.2250    -4397.2365 57814306    0.05%
#  3872976 334340    -4396.9779    54    -4395.2250    -4397.2075 58092140    0.05%
#  3885176 325786    -4397.0155    26    -4395.2250    -4397.1785 58310437    0.04%
# Elapsed time = 598.81 sec. (1016328.82 ticks, tree = 411.08 MB, solutions = 51)
#  3900578 319201    infeasible          -4395.2250    -4397.1470 58471154    0.04%
#  3913197 313175    -4396.9115    57    -4395.2250    -4397.1199 58704636    0.04%
#  3924876 307478        cutoff          -4395.2250    -4397.0859 58881138    0.04%
#  3939787 301699        cutoff          -4395.2250    -4397.0500 59018589    0.04%
#  3954094 293584    infeasible          -4395.2250    -4397.0210 59239332    0.04%
#  3966024 289682    -4395.2458    42    -4395.2250    -4396.9924 59358617    0.04%
#  3979068 282386    -4396.1512    25    -4395.2250    -4396.9582 59563257    0.04%
#  3995084 279344    -4395.8320    30    -4395.2250    -4396.9320 59641965    0.04%
#  4007492 269871        cutoff          -4395.2250    -4396.9015 59905026    0.04%
#  4019789 265138    -4396.6940    19    -4395.2250    -4396.8682 60020668    0.04%
# Elapsed time = 619.62 sec. (1054478.40 ticks, tree = 338.07 MB, solutions = 51)
#  4034489 255427    infeasible          -4395.2250    -4396.8337 60270968    0.04%
#  4048282 248809        cutoff          -4395.2250    -4396.8018 60424866    0.04%
#  4060541 243726        cutoff          -4395.2250    -4396.7642 60534082    0.04%
#  4074211 235790        cutoff          -4395.2250    -4396.7300 60737853    0.03%
#  4088827 228632    -4396.4051    27    -4395.2250    -4396.6767 60908512    0.03%
#  4101533 222079    -4396.4610    20    -4395.2250    -4396.6310 61032429    0.03%
#  4115066 214823    infeasible          -4395.2250    -4396.5930 61185148    0.03%
#  4130244 205718        cutoff          -4395.2250    -4396.5439 61402340    0.03%
#  4142725 195811        cutoff          -4395.2250    -4396.4981 61600601    0.03%
#  4155653 188851    infeasible          -4395.2250    -4396.4506 61744558    0.03%
# Elapsed time = 641.25 sec. (1092627.79 ticks, tree = 247.18 MB, solutions = 51)
#  4171124 182244    -4396.2670    26    -4395.2250    -4396.4020 61864675    0.03%
#  4183765 173225        cutoff          -4395.2250    -4396.3570 62041007    0.03%
#  4197797 163457        cutoff          -4395.2250    -4396.3070 62215110    0.02%
#  4211620 156223        cutoff          -4395.2250    -4396.2520 62370344    0.02%
#  4223923 148362        cutoff          -4395.2250    -4396.2010 62505935    0.02%
#  4239167 140662        cutoff          -4395.2250    -4396.1523 62665179    0.02%
#  4251943 131371    infeasible          -4395.2250    -4396.0985 62834775    0.02%
#  4264555 122571    -4395.9620    13    -4395.2250    -4396.0490 62975762    0.02%
#  4278959 114400        cutoff          -4395.2250    -4395.9877 63117225    0.02%
#  4292705 106220    -4395.8420    28    -4395.2250    -4395.9230 63249340    0.02%
# Elapsed time = 663.17 sec. (1130776.72 ticks, tree = 148.15 MB, solutions = 51)
#  4307579 97657    -4395.7265    46    -4395.2250    -4395.8674 63390357    0.01%
#  4321185 88019        cutoff          -4395.2250    -4395.7972 63527258    0.01%
#  4334809 79750    -4395.6800    19    -4395.2250    -4395.7430 63649778    0.01%
#
# GUB cover cuts applied:  128
# Clique cuts applied:  13
# Cover cuts applied:  731
# Implied bound cuts applied:  2
# Flow cuts applied:  26
# Mixed integer rounding cuts applied:  333
# Zero-half cuts applied:  26
# Lift and project cuts applied:  14
# Gomory fractional cuts applied:  20
#
# Root node processing (before b&c):
#   Real time             =    1.75 sec. (3247.73 ticks)
# Parallel b&c, 10 threads:
#   Real time             =  670.04 sec. (1141747.66 ticks)
#   Sync time (average)   =   78.17 sec.
#   Wait time (average)   =    1.14 sec.
#                           ------------
# Total (root+branch&cut) =  671.79 sec. (1144995.39 ticks)
# solution for: MITB-AI
# objective: -4395.23
# status: OPTIMAL_SOLUTION(2)
# Day_0_GoFrom_DUMMY HOTEL_To_Gardens by the Bay_using_transit=1
# Day_0_GoFrom_Gardens by the Bay_To_Waku Ghin_using_transit=1
# Day_0_GoFrom_Amoy Street Food Centre_To_Sungei Road Laksa_using_transit=1
# Day_0_GoFrom_Waku Ghin_To_Amoy Street Food Centre_using_transit=1
# Day_0_GoFrom_Sungei Road Laksa_To_DUMMY HOTEL_using_transit=1
# Day_1_GoFrom_DUMMY HOTEL_To_Sungei Road Laksa_using_transit=1
# Day_1_GoFrom_Chinatown_To_Waku Ghin_using_transit=1
# Day_1_GoFrom_Amoy Street Food Centre_To_Chinatown_using_transit=1
# Day_1_GoFrom_Waku Ghin_To_DUMMY HOTEL_using_transit=1
# Day_1_GoFrom_Sungei Road Laksa_To_Amoy Street Food Centre_using_transit=1
# Day_2_GoFrom_DUMMY HOTEL_To_Waku Ghin_using_transit=1
# Day_2_GoFrom_Asian Civilisations Museum_To_Amoy Street Food Centre_using_transit=1
# Day_2_GoFrom_Esplanade_To_Merlion Park_using_transit=1
# Day_2_GoFrom_Merlion Park_To_Asian Civilisations Museum_using_transit=1
# Day_2_GoFrom_Singapore Flyer_To_Esplanade_using_transit=1
# Day_2_GoFrom_Amoy Street Food Centre_To_Sungei Road Laksa_using_transit=1
# Day_2_GoFrom_Waku Ghin_To_Singapore Flyer_using_transit=1
# Day_2_GoFrom_Sungei Road Laksa_To_DUMMY HOTEL_using_transit=1
# Day_0_FinishAttraction_DUMMY HOTEL_time=540
# Day_0_FinishAttraction_ArtScience Museum_time=540
# Day_0_FinishAttraction_Asian Civilisations Museum_time=635
# Day_0_FinishAttraction_Chinatown_time=1320
# Day_0_FinishAttraction_Clarke Quay_time=540
# Day_0_FinishAttraction_Esplanade_time=1320
# Day_0_FinishAttraction_Fort Canning Park_time=540
# Day_0_FinishAttraction_Gardens by the Bay_time=720
# Day_0_FinishAttraction_Little India_time=540
# Day_0_FinishAttraction_Marina Bay Sands SkyPark Observation Deck_time=720
# Day_0_FinishAttraction_Merlion Park_time=1320
# Day_0_FinishAttraction_National Gallery Singapore_time=540
# Day_0_FinishAttraction_National Museum of Singapore_time=540
# Day_0_FinishAttraction_Orchard Road_time=540
# Day_0_FinishAttraction_Peranakan Museum_time=540
# Day_0_FinishAttraction_Singapore Botanic Gardens_time=540
# Day_0_FinishAttraction_Singapore Flyer_time=540
# Day_0_FinishAttraction_Lau Pa Sat_time=540
# Day_0_FinishAttraction_Amoy Street Food Centre_time=1225
# Day_0_FinishAttraction_Hill Street Tai Hwa Pork Noodle_time=720
# Day_0_FinishAttraction_Chinatown Complex Food Centre_time=540
# Day_0_FinishAttraction_Odette_time=720
# Day_0_FinishAttraction_JAAN by Kirk Westaway_time=540
# Day_0_FinishAttraction_Cut by Wolfgang Puck_time=540
# Day_0_FinishAttraction_Waku Ghin_time=960
# Day_0_FinishAttraction_Sungei Road Laksa_time=1320
# Day_0_FinishAttraction_Muthu's Curry - Little India_time=540
# Day_0_FinishAttraction_Tekka Centre_time=540
# Day_0_FinishAttraction_Maxwell Food Centre_time=1260
# Day_1_FinishAttraction_DUMMY HOTEL_time=540
# Day_1_FinishAttraction_ArtScience Museum_time=720
# Day_1_FinishAttraction_Asian Civilisations Museum_time=720
# Day_1_FinishAttraction_Chinatown_time=1202
# Day_1_FinishAttraction_Clarke Quay_time=540
# Day_1_FinishAttraction_Esplanade_time=540
# Day_1_FinishAttraction_Fort Canning Park_time=540
# Day_1_FinishAttraction_Gardens by the Bay_time=540
# Day_1_FinishAttraction_Little India_time=720
# Day_1_FinishAttraction_Marina Bay Sands SkyPark Observation Deck_time=540
# Day_1_FinishAttraction_Merlion Park_time=720
# Day_1_FinishAttraction_National Gallery Singapore_time=720
# Day_1_FinishAttraction_National Museum of Singapore_time=540
# Day_1_FinishAttraction_Orchard Road_time=540
# Day_1_FinishAttraction_Peranakan Museum_time=540
# Day_1_FinishAttraction_Singapore Botanic Gardens_time=540
# Day_1_FinishAttraction_Singapore Flyer_time=540
# Day_1_FinishAttraction_Lau Pa Sat_time=720
# Day_1_FinishAttraction_Amoy Street Food Centre_time=1124
# Day_1_FinishAttraction_Hill Street Tai Hwa Pork Noodle_time=720
# Day_1_FinishAttraction_Chinatown Complex Food Centre_time=1020
# Day_1_FinishAttraction_Odette_time=540
# Day_1_FinishAttraction_JAAN by Kirk Westaway_time=720
# Day_1_FinishAttraction_Cut by Wolfgang Puck_time=720
# Day_1_FinishAttraction_Waku Ghin_time=1292
# Day_1_FinishAttraction_Sungei Road Laksa_time=960
# Day_1_FinishAttraction_Muthu's Curry - Little India_time=720
# Day_1_FinishAttraction_Tekka Centre_time=720
# Day_1_FinishAttraction_Maxwell Food Centre_time=720
# Day_2_FinishAttraction_DUMMY HOTEL_time=540
# Day_2_FinishAttraction_ArtScience Museum_time=540
# Day_2_FinishAttraction_Asian Civilisations Museum_time=1140
# Day_2_FinishAttraction_Chinatown_time=540
# Day_2_FinishAttraction_Clarke Quay_time=540
# Day_2_FinishAttraction_Esplanade_time=960
# Day_2_FinishAttraction_Fort Canning Park_time=540
# Day_2_FinishAttraction_Gardens by the Bay_time=1320
# Day_2_FinishAttraction_Little India_time=720
# Day_2_FinishAttraction_Marina Bay Sands SkyPark Observation Deck_time=540
# Day_2_FinishAttraction_Merlion Park_time=1077
# Day_2_FinishAttraction_National Gallery Singapore_time=540
# Day_2_FinishAttraction_National Museum of Singapore_time=540
# Day_2_FinishAttraction_Orchard Road_time=540
# Day_2_FinishAttraction_Peranakan Museum_time=540
# Day_2_FinishAttraction_Singapore Botanic Gardens_time=540
# Day_2_FinishAttraction_Singapore Flyer_time=863
# Day_2_FinishAttraction_Lau Pa Sat_time=540
# Day_2_FinishAttraction_Amoy Street Food Centre_time=1225
# Day_2_FinishAttraction_Hill Street Tai Hwa Pork Noodle_time=720
# Day_2_FinishAttraction_Chinatown Complex Food Centre_time=540
# Day_2_FinishAttraction_Odette_time=600
# Day_2_FinishAttraction_JAAN by Kirk Westaway_time=720
# Day_2_FinishAttraction_Cut by Wolfgang Puck_time=540
# Day_2_FinishAttraction_Waku Ghin_time=650
# Day_2_FinishAttraction_Sungei Road Laksa_time=1320
# Day_2_FinishAttraction_Muthu's Curry - Little India_time=540
# Day_2_FinishAttraction_Tekka Centre_time=660
# Day_2_FinishAttraction_Maxwell Food Centre_time=540
# Day_0_FinishAttraction_DUMMY HOTEL_time_bracket_8=1
# Day_0_FinishAttraction_ArtScience Museum_time_bracket_8=1
# Day_0_FinishAttraction_Asian Civilisations Museum_time_bracket_8=1
# Day_0_FinishAttraction_Chinatown_time_bracket_20=1
# Day_0_FinishAttraction_Clarke Quay_time_bracket_8=1
# Day_0_FinishAttraction_Esplanade_time_bracket_20=1
# Day_0_FinishAttraction_Fort Canning Park_time_bracket_8=1
# Day_0_FinishAttraction_Gardens by the Bay_time_bracket_8=1
# Day_0_FinishAttraction_Little India_time_bracket_8=1
# Day_0_FinishAttraction_Marina Bay Sands SkyPark Observation Deck_time_bracket_8=1
# Day_0_FinishAttraction_Merlion Park_time_bracket_20=1
# Day_0_FinishAttraction_National Gallery Singapore_time_bracket_8=1
# Day_0_FinishAttraction_National Museum of Singapore_time_bracket_8=1
# Day_0_FinishAttraction_Orchard Road_time_bracket_8=1
# Day_0_FinishAttraction_Peranakan Museum_time_bracket_8=1
# Day_0_FinishAttraction_Singapore Botanic Gardens_time_bracket_8=1
# Day_0_FinishAttraction_Singapore Flyer_time_bracket_8=1
# Day_0_FinishAttraction_Lau Pa Sat_time_bracket_8=1
# Day_0_FinishAttraction_Amoy Street Food Centre_time_bracket_20=1
# Day_0_FinishAttraction_Hill Street Tai Hwa Pork Noodle_time_bracket_8=1
# Day_0_FinishAttraction_Chinatown Complex Food Centre_time_bracket_8=1
# Day_0_FinishAttraction_Odette_time_bracket_8=1
# Day_0_FinishAttraction_JAAN by Kirk Westaway_time_bracket_8=1
# Day_0_FinishAttraction_Cut by Wolfgang Puck_time_bracket_8=1
# Day_0_FinishAttraction_Waku Ghin_time_bracket_16=1
# Day_0_FinishAttraction_Sungei Road Laksa_time_bracket_20=1
# Day_0_FinishAttraction_Muthu's Curry - Little India_time_bracket_8=1
# Day_0_FinishAttraction_Tekka Centre_time_bracket_8=1
# Day_0_FinishAttraction_Maxwell Food Centre_time_bracket_20=1
# Day_1_FinishAttraction_DUMMY HOTEL_time_bracket_8=1
# Day_1_FinishAttraction_ArtScience Museum_time_bracket_8=1
# Day_1_FinishAttraction_Asian Civilisations Museum_time_bracket_8=1
# Day_1_FinishAttraction_Chinatown_time_bracket_20=1
# Day_1_FinishAttraction_Clarke Quay_time_bracket_8=1
# Day_1_FinishAttraction_Esplanade_time_bracket_8=1
# Day_1_FinishAttraction_Fort Canning Park_time_bracket_8=1
# Day_1_FinishAttraction_Gardens by the Bay_time_bracket_8=1
# Day_1_FinishAttraction_Little India_time_bracket_8=1
# Day_1_FinishAttraction_Marina Bay Sands SkyPark Observation Deck_time_bracket_8=1
# Day_1_FinishAttraction_Merlion Park_time_bracket_8=1
# Day_1_FinishAttraction_National Gallery Singapore_time_bracket_8=1
# Day_1_FinishAttraction_National Museum of Singapore_time_bracket_8=1
# Day_1_FinishAttraction_Orchard Road_time_bracket_8=1
# Day_1_FinishAttraction_Peranakan Museum_time_bracket_8=1
# Day_1_FinishAttraction_Singapore Botanic Gardens_time_bracket_8=1
# Day_1_FinishAttraction_Singapore Flyer_time_bracket_8=1
# Day_1_FinishAttraction_Lau Pa Sat_time_bracket_8=1
# Day_1_FinishAttraction_Amoy Street Food Centre_time_bracket_16=1
# Day_1_FinishAttraction_Hill Street Tai Hwa Pork Noodle_time_bracket_8=1
# Day_1_FinishAttraction_Chinatown Complex Food Centre_time_bracket_16=1
# Day_1_FinishAttraction_Odette_time_bracket_8=1
# Day_1_FinishAttraction_JAAN by Kirk Westaway_time_bracket_8=1
# Day_1_FinishAttraction_Cut by Wolfgang Puck_time_bracket_8=1
# Day_1_FinishAttraction_Waku Ghin_time_bracket_20=1
# Day_1_FinishAttraction_Sungei Road Laksa_time_bracket_16=1
# Day_1_FinishAttraction_Muthu's Curry - Little India_time_bracket_8=1
# Day_1_FinishAttraction_Tekka Centre_time_bracket_8=1
# Day_1_FinishAttraction_Maxwell Food Centre_time_bracket_8=1
# Day_2_FinishAttraction_DUMMY HOTEL_time_bracket_8=1
# Day_2_FinishAttraction_ArtScience Museum_time_bracket_8=1
# Day_2_FinishAttraction_Asian Civilisations Museum_time_bracket_16=1
# Day_2_FinishAttraction_Chinatown_time_bracket_8=1
# Day_2_FinishAttraction_Clarke Quay_time_bracket_8=1
# Day_2_FinishAttraction_Esplanade_time_bracket_16=1
# Day_2_FinishAttraction_Fort Canning Park_time_bracket_8=1
# Day_2_FinishAttraction_Gardens by the Bay_time_bracket_20=1
# Day_2_FinishAttraction_Little India_time_bracket_8=1
# Day_2_FinishAttraction_Marina Bay Sands SkyPark Observation Deck_time_bracket_8=1
# Day_2_FinishAttraction_Merlion Park_time_bracket_16=1
# Day_2_FinishAttraction_National Gallery Singapore_time_bracket_8=1
# Day_2_FinishAttraction_National Museum of Singapore_time_bracket_8=1
# Day_2_FinishAttraction_Orchard Road_time_bracket_8=1
# Day_2_FinishAttraction_Peranakan Museum_time_bracket_8=1
# Day_2_FinishAttraction_Singapore Botanic Gardens_time_bracket_8=1
# Day_2_FinishAttraction_Singapore Flyer_time_bracket_12=1
# Day_2_FinishAttraction_Lau Pa Sat_time_bracket_8=1
# Day_2_FinishAttraction_Amoy Street Food Centre_time_bracket_20=1
# Day_2_FinishAttraction_Hill Street Tai Hwa Pork Noodle_time_bracket_8=1
# Day_2_FinishAttraction_Chinatown Complex Food Centre_time_bracket_8=1
# Day_2_FinishAttraction_Odette_time_bracket_8=1
# Day_2_FinishAttraction_JAAN by Kirk Westaway_time_bracket_8=1
# Day_2_FinishAttraction_Cut by Wolfgang Puck_time_bracket_8=1
# Day_2_FinishAttraction_Waku Ghin_time_bracket_8=1
# Day_2_FinishAttraction_Sungei Road Laksa_time_bracket_20=1
# Day_2_FinishAttraction_Muthu's Curry - Little India_time_bracket_8=1
# Day_2_FinishAttraction_Tekka Centre_time_bracket_8=1
# Day_2_FinishAttraction_Maxwell Food Centre_time_bracket_8=1
# Day_0_LastVisitIs_Sungei Road Laksa=1
# Day_1_LastVisitIs_Waku Ghin=1
# Day_2_LastVisitIs_Sungei Road Laksa=1
# Day_0_VisitHawker_Hill Street Tai Hwa Pork Noodle_inLunchTime=1
# Day_1_VisitHawker_Lau Pa Sat_inLunchTime=1
# Day_2_VisitHawker_Tekka Centre_inLunchTime=1
# Day_0_VisitHawker_Maxwell Food Centre_inDinnerTime=1
# Day_1_VisitHawker_Chinatown Complex Food Centre_inDinnerTime=1
# Day_2_VisitHawker_Amoy Street Food Centre_inDinnerTime=1
# total_cost=992.850
# total_travel_time=2119.250
# total_satisfaction=70.000

# %%
for day in range(NUM_DAYS):
    print(f"Day {day}:")
    
    # Find starting location (hotel) and its start time
    start_location = locations[0]["name"]
    start_time = round(u_var[(day, start_location)].solution_value)
    print(f"- Start at {start_location} by {int(start_time // 60):02d}:{int(start_time % 60):02d}")

    current_location = start_location
    while True:
        next_location = None
        chosen_transport = None
        travel_time = None
        price = None
        entrance_fee = None
        duration = None
        food_price = None

        # Find the next location and transport used
        for transport_type in transport_types:
            for dest in locations:
                if dest["name"] == current_location:
                    continue
                
                for time_bracket in time_brackets:
                    if x_var[(day, transport_type, current_location, dest["name"])].solution_value > 0.5:
                        next_location = dest["name"]
                        chosen_transport = transport_type
                        travel_time = transport_matrix[(current_location, next_location, time_bracket)][transport_type]["duration"]
                        price = transport_matrix[(current_location, next_location, time_bracket)][transport_type]["price"]
                        entrance_fee = dest.get("entrance_fee", 0) if dest["type"] == "attraction" else None
                        duration = (dest.get("duration", 0) // 60, dest.get("duration", 0) % 60)
                        food_price = dest.get("avg_food_price", 0) if dest["type"] == "hawker" else None
                        break
                if next_location:
                    break
            if next_location:
                break
        
        if not next_location:
            break  # No more locations for the day

        # Arrival time
        arrival_time = u_var[(day, next_location)].solution_value

        # Print movement details
        print(f"- Go to {next_location} using {chosen_transport}, travel time is {travel_time} min, price is ${price:.2f}", end="")

        if entrance_fee:
            print(f", entrance fee is ${entrance_fee:.2f}", end="")
        if duration and next_location != "DUMMY HOTEL":
            print(f", you'll be there for {duration[0]} hours {duration[1]} minutes", end="")
        if food_price:
            print(f", average food price is ${food_price:.2f}", end="")

        if next_location != "DUMMY HOTEL": print(f", finish by {int(arrival_time // 60):02d}:{int(arrival_time % 60):02d}.")

        if next_location == "DUMMY HOTEL":
            # stop because reach hotel already
            break

        current_location = next_location

    print()  # Blank line between days
# Out:
# Day 0:
# - Start at DUMMY HOTEL by 09:00
# - Go to Gardens by the Bay using transit, travel time is 50 min, price is $1.93, entrance fee is $11.00, you'll be there for 1 hours 29 minutes, finish by 12:00.
# - Go to Waku Ghin using transit, travel time is 19.57 min, price is $1.19, you'll be there for 1 hours 0 minutes, average food price is $5.00, finish by 16:00.
# - Go to Amoy Street Food Centre using transit, travel time is 23.4 min, price is $1.19, you'll be there for 1 hours 0 minutes, average food price is $9.00, finish by 20:25.
# - Go to Sungei Road Laksa using transit, travel time is 24.28 min, price is $1.50, you'll be there for 1 hours 0 minutes, average food price is $9.00, finish by 22:00.
# - Go to DUMMY HOTEL using transit, travel time is 50 min, price is $1.93, finish by 08:59.
#
# Day 1:
# - Start at DUMMY HOTEL by 09:00
# - Go to Sungei Road Laksa using transit, travel time is 50 min, price is $1.93, you'll be there for 1 hours 0 minutes, average food price is $9.00, finish by 16:00.
# - Go to Amoy Street Food Centre using transit, travel time is 25.0 min, price is $1.50, you'll be there for 1 hours 0 minutes, average food price is $9.00, finish by 18:44.
# - Go to Chinatown using transit, travel time is 9.18 min, price is $1.19, entrance fee is $18.00, you'll be there for 1 hours 8 minutes, finish by 20:02.
# - Go to Waku Ghin using transit, travel time is 19.58 min, price is $1.19, you'll be there for 1 hours 0 minutes, average food price is $5.00, finish by 21:32.
# - Go to DUMMY HOTEL using transit, travel time is 50 min, price is $1.93, finish by 08:59.
#
# Day 2:
# - Start at DUMMY HOTEL by 09:00
# - Go to Waku Ghin using transit, travel time is 50 min, price is $1.93, you'll be there for 1 hours 0 minutes, average food price is $5.00, finish by 10:50.
# - Go to Singapore Flyer using transit, travel time is 17.47 min, price is $1.19, entrance fee is $10.00, you'll be there for 1 hours 9 minutes, finish by 14:23.
# - Go to Esplanade using transit, travel time is 12.18 min, price is $1.19, entrance fee is $29.00, you'll be there for 1 hours 24 minutes, finish by 16:00.
# - Go to Merlion Park using transit, travel time is 6.23 min, price is $1.19, entrance fee is $37.00, you'll be there for 1 hours 27 minutes, finish by 17:57.
# - Go to Asian Civilisations Museum using transit, travel time is 8.75 min, price is $1.19, entrance fee is $10.00, you'll be there for 0 hours 54 minutes, finish by 19:00.
# - Go to Amoy Street Food Centre using transit, travel time is 16.58 min, price is $1.19, you'll be there for 1 hours 0 minutes, average food price is $9.00, finish by 20:25.
# - Go to Sungei Road Laksa using transit, travel time is 24.28 min, price is $1.50, you'll be there for 1 hours 0 minutes, average food price is $9.00, finish by 22:00.
# - Go to DUMMY HOTEL using transit, travel time is 50 min, price is $1.93, finish by 08:59.
